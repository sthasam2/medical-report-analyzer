# %% [markdown]
# # NER of Medical Reports using stana, spacy
#
# Name Entity recognition is is a subtask of information extraction that seeks to locate and classify named entities mentioned in unstructured text into pre-defined categories such as person names, organizations, locations, medical codes, time expressions, quantities, monetary values, percentages, etc.
#
# We perform NER on Medical Transcript samples we scraped from <https://medical-transcription-sample-reports.blogspot.com/>

# %% [markdown]
# ## Importing and Installing Requirements
#
# We need to install dependencies, as well as download some models manually for running NER. Additional models and dependencies are also installed during notebook execution.
#
# ### Prerequisite Dependencies
# - spacy
# - spacy_stanza
# - en_core_web_lg(stanza english model)

# %% [markdown]
# *NOTE: Apply this function only the first time using model. The model is large at 500MBs and running everytime will download model everytime*

# %%
# downloading spacy english model
# !python -m spacy download en_core_web_lg

# %% [markdown]
# ### Importing required libraries

# %%
import pprint
import spacy
import spacy_stanza

from spacy import displacy
from spacytextblob.spacytextblob import SpacyTextBlob

# %% [markdown]
# ## Create a sample record for testing

# %%
sample_record = """
John Doe from Banepa, Dhulikhel studying at Kathmandu University, age 20, complains of mild joint pains.
He also suffers from frequent cramps on his legs. His X-ray scan showed no issues with bones.
After a vitamin D test, it is seen that his vitamin D is just 7.6 mg.
He has been prescribed VitaD sachets and some calcium tablets.
"""

# %% [markdown]
# ## Create NER pipeline
#
# Create a pipeline for NER processing using stanza. It uses pretrained ner models like i2b2, radiology, etc
#
# This downloads the required packages and models

# %%
ner_pipeline = spacy_stanza.load_pipeline(
    "en",
    processors={"ner": [
        "i2b2",
        "radiology",
        "ontonotes",
        ],"tokenize": 'combined',
    },
    package='',
        
)
# Out:
# 2022-12-11 20:52:07 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2022-12-11 20:52:09 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 20:52:09 INFO: Use device: gpu
# 2022-12-11 20:52:09 INFO: Loading: tokenize
# 2022-12-11 20:52:11 INFO: Loading: ner
# 2022-12-11 20:52:13 INFO: Done loading processors!

# %% [markdown]
# ## Passing the sample through the Model Pipeline

# %% [markdown]
# First we pass the sample through NER pipeline for NER using the defined models

# %%
ner_doc = ner_pipeline(sample_record)

# %% [markdown]
# We also pass it through the sentiment pipeline we define below to know the overall entiment of the report

# %%
# defining pipelines for sentiment
sentiment_pipeline = spacy.load("en_core_web_lg")
sentiment_pipeline.add_pipe("spacytextblob")

# %%
# passing sample through sentiment
sentiment_doc = sentiment_pipeline(sample_record)

# %% [markdown]
# ## Storing Output
#
# Storing the pipelined i.e. model tested data output in a dictionary format. Here we store both NER and Sentiment outputs.

# %%
extracted_record = {}
for entity in ner_doc.ents:
    if entity.label_ in extracted_record:
        if str(entity) not in extracted_record[entity.label_]:
            extracted_record[entity.label_].append(str(entity))
    else:
        extracted_record[entity.label_] = [str(entity)]
        
extracted_record["SENTIMENT"] = round(sentiment_doc._.blob.polarity, 5)

# %% [markdown]
# ## Displaying Output Extracted Data

# %%
pprint.pprint(extracted_record)
# Out:
# {'DATE': ['age 20'],
#  'GPE': ['Banepa', 'Dhulikhel'],
#  'ORG': ['Kathmandu University'],
#  'PERSON': ['John Doe'],
#  'PROBLEM': ['mild joint pains',
#              'frequent cramps on his legs',
#              'issues with bones'],
#  'QUANTITY': ['7.6 mg'],
#  'SENTIMENT': -0.05556,
#  'TEST': ['His X-ray scan', 'a vitamin D test'],
#  'TREATMENT': ['his vitamin D', 'VitaD sachets', 'some calcium tablets'],
#  'UNCERTAINTY': ['no']}

# %% [markdown]
# ## Displaying Extracted Data Annotated in the document

# %%
displacy.render(ner_doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Doe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Banepa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dhulikhel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  studying at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kathmandu University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     age 20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , complains of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mild joint pains
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# .</br>He also suffers from
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     frequent cramps on his legs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     His X-ray scan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
#  showed
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     no
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">UNCERTAINTY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     issues with bones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# .</br>After
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a vitamin D test
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TEST</span>
# </mark>
# , it is seen that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     his vitamin D
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TREATMENT</span>
# </mark>
#  is just
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7.6 mg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# .</br>He has been prescribed
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VitaD sachets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TREATMENT</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     some calcium tablets
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TREATMENT</span>
# </mark>
# .</br></div></span>

# %% [markdown]
# # Performing the Test with Medical Record Sample
#
# We now define a function so that we can use the medical transcripts stored in txt files to pass through the NER and Sentiment pipelines. So, essentially a function to apply the defined models

# %%
def extract_info(filename: str, visualize: bool = True) -> None:
    with open(filename, "r") as inp:
        content = inp.read()
    
    ner_pipeline = spacy_stanza.load_pipeline(
        "en",
        processors={"ner": [
            "i2b2",
            "radiology",
            "ontonotes",
            ],"tokenize": 'combined',
        },
        package="",    
    )
    
    sentiment_pipeline = spacy.load("en_core_web_lg")
    sentiment_pipeline.add_pipe("spacytextblob")
    
    ner_doc = ner_pipeline(content)
    sentiment_doc = sentiment_pipeline(content)
    
    extracted_record = {}
    for entity in ner_doc.ents:
        if entity.label_ in extracted_record:
            if str(entity) not in extracted_record[entity.label_]:
                extracted_record[entity.label_].append(str(entity))
        else:
            extracted_record[entity.label_] = [str(entity)]

    extracted_record["SENTIMENT"] = round(sentiment_doc._.blob.polarity, 5)
    
    if visualize:
        displacy.render(ner_doc, style="ent", jupyter=True)
        
    pprint.pprint(extracted_record)

# %% [markdown]
# ## Applying to a Transcript and displaying Output
#
# Apply pipeline to report_15.txt

# %%
extract_info("assets/txt_reports/report_15.txt")
# Out:
# 2022-12-11 20:52:15 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2022-12-11 20:52:16 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 20:52:16 INFO: Use device: gpu
# 2022-12-11 20:52:16 INFO: Loading: tokenize
# 2022-12-11 20:52:16 INFO: Loading: ner
# 2022-12-11 20:52:17 INFO: Done loading processors!
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arthroscopic Subacromial Decompression
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TREATMENT</span>
# </mark>
#  Sample Report</br></br>DATE OF OPERATION: </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MM/DD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# /YYYY</br> </br>PREOPERATIVE DIAGNOSIS: </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Right rotator cuff tear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# .</br> </br>POSTOPERATIVE DIAGNOSES:</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Right rotator cuff tear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     subscapularis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     supraspinatus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
# .</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Right labral tear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# .</br>OPERATION PERFORMED:</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Right arthroscopic subacromial decompression
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TREATMENT</span>
# </mark>
# .</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Right arthroscopic extensive debridement
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TREATMENT</span>
# </mark>
#  to include the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     labrum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     subscapularis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     supraspinatus tendons
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
# .</br> </br>SURGEON: </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Doe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MD
# ASSISTANT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# : </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jane Doe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , MD</br>ANESTHESIA: </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Scalene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
# .</br>TOURNIQUET TIME: </br>None.</br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ESTIMATED BLOOD LOSS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PROBLEM</span>
# </mark>
# : </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Less than 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  mL.</br>COMPLICATIONS: </br>None.</br>DRAINS: </br>None.</br>INDICATIONS FOR OPERATION: </br>The patient is a (XX)-year-old
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hispanic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  male who injured his
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     right
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY_MODIF
# {'ANATOMY': ['subscapularis',
#              'supraspinatus',
#              'labrum',
#              'supraspinatus tendons',
#              'Scalene',
#              'shoulder',
#              'cervical spine',
#              'arm',
#              'upper extremity',
#              'neck',
#              'portal',
#              'biceps',
#              'axillary',
#              'pouch',
#              'glenohumeral ligament',
#              'subacromial',
#              'bone',
#              'right upper extremity'],
#  'ANATOMY_MODIFIER': ['right',
#                       'lateral',
#                       'base',
#                       'posterior',
#                       'anterolateral',
#                       'superior',
#                       'anchor',
#                       'anteroinferior',
#                       'inferior',
#                       'rest',
#                       'middle',
#                       'anterior',
#                       'band',
#                       'region'],
#  'CARDINAL': ['1', '2', 'Less than 5', '4/4'],
#  'NORP': ['Hispanic'],
#  'OBSERVATION': ['within normal limits',
#                  'debrided',
#                  'repairable',
#                  'cuff',
#                  'resected',
#                  'stable'],
#  'OBSERVATION_MODIFIER': ["11 o'clock",
#                           'position',
#                           'amounts',
#                           '6 mm',
#                           'smooth',
#                           'flat',
#                           'surface'],
#  'ORG': ['MM/DD'],
#  'PERCENT': ['5%'],
#  'PERSON': ['John Doe', 'MD\nASSISTANT', 'Jane Doe'],
#  'PROBLEM': ['Right rotator cuff tear',
#              'Right labral tear',
#              'ESTIMATED BLOOD LOSS',
#              'a pulling sensation',
#              'pain',
#              'pain complaints',
#              'a rotator cuff tear',
#              'continued pain complaints',
#              'significant fraying',
#              'some detachment',
#              'the degenerative nature',
#              'loose bodies',
#              'significant degenerative changes',
#              'a partial tear of the subscapularis',
#              'some mild delamination',
#              'defects',
#              'tearing',
#              'fraying',
#              'some mild delamination at the articular surface',
#              'a PASTA lesion',
#              'neovascularization',
#              'a hypertrophic, thickened subacromial bursa',
#              'A moderately thickened coracoacromial ligament',
#              'A moderate-sized enthesiophyte',
#              'a flat smooth acromion',
#              'partial tears',
#              'estimated blood loss',
#              'The wounds',
#              'scalene block'],
#  'QUANTITY': ["1 o'clock", '4-0 nylon', 'less than 5 mL'],
#  'SENTIMENT': 0.09954,
#  'TEST': ['physical examination',
#           'plain film radiographs',
#           'an MRI scan',
#           'bony palpation',
#           'The humeral head and glenoid fossa',
#           'Further probing',
#           'The rotator interval',
#           'Inspection of the bursal side of the rotator cuff',
#           'instrument counts',
#           'Examination',
#           'the radial pulse',
#           'neurologic examination'],
#  'TREATMENT': ['Arthroscopic Subacromial Decompression',
#                'Right arthroscopic subacromial decompression',
#                'Right arthroscopic extensive debridement',
#                'the above-mentioned operation',
#                'scalene block',
#                'preoperative antibiotics',
#                'Betadine',
#                'a 15 scalpel blade',
#                'the arthroscope',
#                'outflow and instrumentation',
#                'A radiofrequency device',
#                'formal repair',
#                'a 5.5 full radius shaver',
#                'a radiofrequency device',
#                'The arthroscope',
#                'instrumentation',
#                'A formal bursectomy',
#                'A formal acromioplasty',
#                'Resection',
#                'an adequate subacromial decompression',
#                'extensive debridement of the labrum, supraspinatus and '
#                'subscapularis',
#                'The instruments',
#                'All sponge',
#                'A Polar Care ice machine',
#                'a shoulder immobilizer'],
#  'UNCERTAINTY': ['no']}
