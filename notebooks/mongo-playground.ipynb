# %% [markdown]
# # Exporting Extracted Medical Records to MongoDB
#
# As a means of storage, we export out our extracted data from the reports to MongoDB

# %% [markdown]
# ## Import pymongo, a MongoDB client for python

# %%
from pymongo import MongoClient

# %% [markdown]
# ## Connect to a MongodDB cluster
#
# After creating a cluster in MongoDB atlas, we can connect to it using the credentials provided

# %%
cluster = "mongodb+srv://ai-champions:N8hObJPzoQamtWOn@cluster0.eesjih9.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(cluster)

# %% [markdown]
# ## Check MongoDB databases

# %%
client.list_database_names()
# Out:
# ['ai_project', 'admin', 'local']

# %% [markdown]
# We already have a database created, named 'ai_project' from the atlas console

# %% [markdown]
# ## Select a database to perform actions
#
# From the ;ist above, we choose a db

# %%
db = client["ai_project"]

# %% [markdown]
# ## List collections in the database
#
# We store data records in collections in MongoDB, we created a collection named "extracted_medical_records" in the database.

# %%
db.list_collection_names()
# Out:
# ['extracted_medical_records']

# %% [markdown]
# ## Test adding a record into the collection
#
# Let's create a dummy data to add into the collection

# %%
record = {
    'DATE': ['age 20'],
    'GPE': ['Banepa', 'Dhulikhel'],
    'ORG': ['Kathmandu University'],
    'PERSON': ['John Doe'],
    'RAILA': 'Solti'
}

# %%
# select a collectioo
extracted_medical_records = db["extracted_medical_records"]

# Add record
extracted_medical_records.insert_one(record)

# %% [markdown]
# ## Extract NER data from records and store it in MongoDB
#
# We then perfom NER on sample data and then store the result in MongoDB

# %%
# import ner fuction
from ner.medical_ner import extract_data

# %% [markdown]
# ### Apply NER only on the first 10 records, and then store it

# %%
records = []

for i in range(10):
    records.append(extract_data(f"assets/txt_records/report_{i}.txt"))
# Out:
# 2022-12-11 18:15:01 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 10.3MB/s]
# 2022-12-11 18:15:03 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:15:03 INFO: Use device: gpu
# 2022-12-11 18:15:03 INFO: Loading: tokenize
# 2022-12-11 18:15:06 INFO: Loading: ner
# 2022-12-11 18:15:08 INFO: Done loading processors!
# 2022-12-11 18:15:14 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 7.55MB/s]
# 2022-12-11 18:15:16 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:15:16 INFO: Use device: gpu
# 2022-12-11 18:15:16 INFO: Loading: tokenize
# 2022-12-11 18:15:16 INFO: Loading: ner
# 2022-12-11 18:15:17 INFO: Done loading processors!
# 2022-12-11 18:15:22 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 7.22MB/s]
# 2022-12-11 18:15:23 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:15:23 INFO: Use device: gpu
# 2022-12-11 18:15:23 INFO: Loading: tokenize
# 2022-12-11 18:15:23 INFO: Loading: ner
# 2022-12-11 18:15:24 INFO: Done loading processors!
# 2022-12-11 18:15:28 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 7.34MB/s]
# 2022-12-11 18:15:29 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:15:29 INFO: Use device: gpu
# 2022-12-11 18:15:29 INFO: Loading: tokenize
# 2022-12-11 18:15:29 INFO: Loading: ner
# 2022-12-11 18:15:31 INFO: Done loading processors!
# 2022-12-11 18:15:38 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 6.93MB/s]
# 2022-12-11 18:15:39 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:15:39 INFO: Use device: gpu
# 2022-12-11 18:15:39 INFO: Loading: tokenize
# 2022-12-11 18:15:39 INFO: Loading: ner
# 2022-12-11 18:15:40 INFO: Done loading processors!
# 2022-12-11 18:15:45 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 6.58MB/s]
# 2022-12-11 18:15:47 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:15:47 INFO: Use device: gpu
# 2022-12-11 18:15:47 INFO: Loading: tokenize
# 2022-12-11 18:15:47 INFO: Loading: ner
# 2022-12-11 18:15:48 INFO: Done loading processors!
# 2022-12-11 18:15:52 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 5.51MB/s]
# 2022-12-11 18:15:54 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:15:54 INFO: Use device: gpu
# 2022-12-11 18:15:54 INFO: Loading: tokenize
# 2022-12-11 18:15:54 INFO: Loading: ner
# 2022-12-11 18:15:56 INFO: Done loading processors!
# 2022-12-11 18:16:03 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 7.95MB/s]
# 2022-12-11 18:16:04 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:16:04 INFO: Use device: gpu
# 2022-12-11 18:16:04 INFO: Loading: tokenize
# 2022-12-11 18:16:04 INFO: Loading: ner
# 2022-12-11 18:16:05 INFO: Done loading processors!
# 2022-12-11 18:16:10 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 8.11MB/s]
# 2022-12-11 18:16:11 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:16:11 INFO: Use device: gpu
# 2022-12-11 18:16:11 INFO: Loading: tokenize
# 2022-12-11 18:16:11 INFO: Loading: ner
# 2022-12-11 18:16:13 INFO: Done loading processors!
# 2022-12-11 18:16:17 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 7.29MB/s]
# 2022-12-11 18:16:18 INFO: Loading these models for language: en (English):
# ========================================
# | Processor | Package                  |
# ----------------------------------------
# | tokenize  | combined                 |
# | ner       | i2b2;radiology;ontonotes |
# ========================================
#
# 2022-12-11 18:16:18 INFO: Use device: gpu
# 2022-12-11 18:16:18 INFO: Loading: tokenize
# 2022-12-11 18:16:18 INFO: Loading: ner
# 2022-12-11 18:16:20 INFO: Done loading processors!

# %% [markdown]
# ### After applying NER, we get the following data from the report

# %%
records[1]
# Out:
# {'TREATMENT': ['Left Heart Catheterization',
#   'the procedure',
#   '2% lidocaine',
#   'A 6 French sheath',
#   'modified Seldinger technique',
#   'A 6 French angled pigtail',
#   'aortic valve pullback',
#   '6 French JL4 and JR4 catheters',
#   'a previously placed stent',
#   'the stent',
#   'a previous stent',
#   'a previously placed stent in the mid vessel',
#   'The previously placed stent in the proximal and middle vessel',
#   'a previously placed stent in the distal vessel'],
#  'ANATOMY_MODIFIER': ['right',
#   'interventricular',
#   'groove',
#   'apex',
#   'proximal',
#   'mid',
#   'diagonal',
#   'branch',
#   'distal',
#   'portion',
#   'left',
#   'anterior',
#   'descending',
#   'marginal',
#   'obtuse'],
#  'ANATOMY': ['groin',
#   'right femoral artery',
#   'coronary',
#   'main artery',
#   'vessel',
#   'anterior descending artery',
#   'circumflex artery',
#   'coronary artery',
#   'ventricle'],
#  'TEST': ['left ventriculography',
#   'selective coronary angiography',
#   'Multiple views',
#   'the prior angiogram',
#   'Ejection fraction',
#   'The left ventricular end diastolic pressure'],
#  'OBSERVATION': ['dominant', 'flow', 'patent', '65%'],
#  'OBSERVATION_MODIFIER': ['long',
#   'large',
#   'caliber',
#   'coursed',
#   'unchanged',
#   'area',
#   'widely',
#   'course',
#   'second',
#   'obtuse',
#   'medium',
#   'third',
#   'acute',
#   'small'],
#  'PROBLEM': ['minimal 10-20% narrowing',
#   'diffuse in-stent re-stenosis',
#   'tortuosity',
#   'ectasia',
#   'a 40-50% narrowing in its mid portion',
#   'mild diffuse nonobstructive disease',
#   '30% narrowing at its ostium',
#   'a focal 40-50% narrowing in the mid to distal portion',
#   '30% diffuse narrowing',
#   '30% diffuse mild in-stent re-stenosis',
#   '40-50% diffuse disease',
#   'an ostial 90% stenosis',
#   'wall motion abnormalities',
#   'mitral regurgitation',
#   'aortic valve gradient'],
#  'PERCENT': ['40-50%'],
#  'UNCERTAINTY': ['did not appear to be', 'no'],
#  'ORDINAL': ['second'],
#  'CARDINAL': ['12'],
#  'SENTIMENT': 0.02055}

# %% [markdown]
# ### Insert records to MongoDB
#
# We can interatively insert the records by using '*insert_one*' function or use '*insert_many*'

# %%
for record in records:
    extracted_medical_records.insert_one(record)

# %% [markdown]
# ### Display data from the database
#
# We can display the data available in the MongoDB collection as follows

# %%
import pprint

cursor = extracted_medical_records.find({})
for document in cursor:
      pprint.pprint(document)
# Out:
# {'DATE': ['age 20'],
#  'GPE': ['Banepa', 'Dhulikhel'],
#  'ORG': ['Kathmandu University'],
#  'PERSON': ['John Doe'],
#  'RAILA': 'Solti',
#  '_id': ObjectId('6395c92f4fe5e6d8f7437c72')}
# {'ANATOMY': ['fascia',
#              'midline',
#              'rectus muscle',
#              'peritoneum',
#              'bladder',
#              'uterus',
#              'bowel',
#              'peritoneal',
#              'ligament',
#              'ovaries',
#              'broad ligament',
#              'uterine arteries',
#              'uterosacral ligaments',
#              'cervix',
#              'ovary',
#              'ureter',
#              'ovarian',
#              'peritoneal cavity',
#              'pelvis'],
#  'ANATOMY_MODIFIER': ['dorsal',
#                       'layer',
#                       'superiorly',
#                       'left',
#                       'lateral',
#                       'wall',
#                       'anterior',
#                       'bilaterally',
#                       'right'],
#  'OBSERVATION': ['incised',
#                  'dissected',
#                  'incision',
#                  'visualization',
#                  'packed',
#                  'clamped',
#                  'skeletonized',
#                  'palpated',
#                  'tissue',
#                  'adherent',
#                  'stable'],
#  'OBSERVATION_MODIFIER': ['superior',
#                           'elevated',
#                           'sharply',
#                           'inferior',
#                           'inferiorly',
#                           'good',
#                           'round',
#                           'transected',
#                           'ligated',
#                           'very'],
#  'ORG': ['MM/DD'],
#  'PERSON': ['John Doe'],
#  'PROBLEM': ['dense adhesions in the subcutaneous tissue',
#              'the incision',
#              'filmy adhesions',
#              'dense bowel adhesions to the peritoneal wall',
#              'difficulty',
#              'These adhesions in the bladder',
#              'manipulation at the cornua',
#              'a cyst',
#              'clear cystic fluid',
#              'the anticipated potential blood loss',
#              'complications to bowel',
#              'a small amount of bleeding at the site',
#              'a small amount of bleeding at the posterior cuff',
#              'further adhesions',
#              'Subcutaneous tissue',
#              'complications'],
#  'SENTIMENT': 0.06815,
#  'TEST': ['examination of the pelvis', 'Hemostasis'],
#  'TREATMENT': ['Total Abdominal Hysterectomy',
#                'IV running',
#                'General anesthesia',
#                'The initial skin incision',
#                'a scalpel',
#                'the curved Mayo scissors',
#                'Kocher clamps',
#                'peritoneal incision',
#                'a retractor',
#                'the Bookwalter retractor',
#                'moist laparotomy sponges',
#                'Metzenbaum scissors',
#                'suture',
#                'total abdominal hysterectomy',
#                'potential removal',
#                'A window',
#                'the tubo-ovarian ligaments',
#                '0 Vicryl suture bilaterally',
#                'Hemostasis',
#                'Zeppelin clamps',
#                'suture ligated',
#                'the Jorgensen scissors',
#                'Vaginal cuff angles',
#                'figure-of-eight 0 Vicryl suture',
#                'the vaginal cuff',
#                'a series of interrupted 0 Vicryl sutures',
#                'the IP ligament',
#                'this ovary',
#                '2-0 Vicryl sutures',
#                '2-0 Vicryl suture',
#                'All instruments',
#                'Seprafilm',
#                'All sponges',
#                'laps and needles',
#                'The fascia',
#                '0 Vicryl suture',
#                '3-0 Vicryl suture',
#                'staples',
#                'a sterile dressing',
#                'the procedure'],
#  '_id': ObjectId('6395ce5a4fe5e6d8f7437c73')}
# {'ANATOMY': ['groin',
#              'right femoral artery',
#              'coronary',
#              'main artery',
#              'vessel',
#              'anterior descending artery',
#              'circumflex artery',
#              'coronary artery',
#              'ventricle'],
#  'ANATOMY_MODIFIER': ['right',
#                       'interventricular',
#                       'groove',
#                       'apex',
#                       'proximal',
#                       'mid',
#                       'diagonal',
#                       'branch',
#                       'distal',
#                       'portion',
#                       'left',
#                       'anterior',
#                       'descending',
#                       'marginal',
#                       'obtuse'],
#  'CARDINAL': ['12'],
#  'OBSERVATION': ['dominant', 'flow', 'patent', '65%'],
#  'OBSERVATION_MODIFIER': ['long',
#                           'large',
#                           'caliber',
#                           'coursed',
#                           'unchanged',
#                           'area',
#                           'widely',
#                           'course',
#                           'second',
#                           'obtuse',
#                           'medium',
#                           'third',
#                           'acute',
#                           'small'],
#  'ORDINAL': ['second'],
#  'PERCENT': ['40-50%'],
#  'PROBLEM': ['minimal 10-20% narrowing',
#              'diffuse in-stent re-stenosis',
#              'tortuosity',
#              'ectasia',
#              'a 40-50% narrowing in its mid portion',
#              'mild diffuse nonobstructive disease',
#              '30% narrowing at its ostium',
#              'a focal 40-50% narrowing in the mid to distal portion',
#              '30% diffuse narrowing',
#              '30% diffuse mild in-stent re-stenosis',
#              '40-50% diffuse disease',
#              'an ostial 90% stenosis',
#              'wall motion abnormalities',
#              'mitral regurgitation',
#              'aortic valve gradient'],
#  'SENTIMENT': 0.02055,
#  'TEST': ['left ventriculography',
#           'selective coronary angiography',
#           'Multiple views',
#           'the prior angiogram',
#           'Ejection fraction',
#           'The left ventricular end diastolic pressure'],
#  'TREATMENT': ['Left Heart Catheterization',
#                'the procedure',
#                '2% lidocaine',
#                'A 6 French sheath',
#                'modified Seldinger technique',
#                'A 6 French angled pigtail',
#                'aortic valve pullback',
#                '6 French JL4 and JR4 catheters',
#                'a previously placed stent',
#                'the stent',
#                'a previous stent',
#                'a previously placed stent in the mid vessel',
#                'The previously placed stent in the proximal and middle vessel',
#                'a previously placed stent in the distal vessel'],
#  'UNCERTAINTY': ['did not appear to be', 'no'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c74')}
# {'ANATOMY': ['vocal  folds',
#              'vocal fold',
#              'larynx',
#              'oral cavity',
#              'subglottis',
#              'trachea',
#              'carina',
#              'neck'],
#  'ANATOMY_MODIFIER': ['posterior', 'right', 'true'],
#  'OBSERVATION': ['vocal process', 'vocal folds', 'good positioning', 'stable'],
#  'OBSERVATION_MODIFIER': ['large', 'amount', 'small', 'entrance'],
#  'ORDINAL': ['first'],
#  'ORG': ['MM/DD'],
#  'PERSON': ['John Doe'],
#  'PROBLEM': ['redundant soft tissue',
#              'discrete mass',
#              'lesion in the oropharynx or hypopharynx',
#              'soft tissue',
#              'lingual tonsillar hypertrophy',
#              'postcricoid edema',
#              'gastroesophageal reflux disease',
#              "a mild to moderate amount of Reinke's edema",
#              'resolving ecchymosis',
#              'other significant trauma',
#              'visible fixed obstruction at this level',
#              'tracheomalacia',
#              'masses',
#              'lesions'],
#  'SENTIMENT': 0.14518,
#  'TEST': ['Direct Laryngoscopy'],
#  'TREATMENT': ['General  anesthesia',
#                'ventilated',
#                'an already intact  tracheostomy tube',
#                'Anterior commissure laryngoscope',
#                'the bronchoscope',
#                'the tracheostomy tube',
#                'the #6 extended length Shiley',
#                'a #5 uncuffed extended  length Shiley',
#                'the already intact tracheotomy',
#                'The bronchoscope',
#                'laryngoscope',
#                'The  bronchoscope',
#                'The new tracheostomy tube',
#                'Fiberoptic Bronchoscopy'],
#  'UNCERTAINTY': ['no', 'consistent with', 'seemed to be'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c75')}
# {'ANATOMY': ['Neck',
#              'neck',
#              'skin',
#              'sternocleidomastoid muscles',
#              'fascia',
#              'muscle',
#              'fat',
#              'spinal  accessory nerve',
#              'nerve',
#              'cervical roots',
#              'cervical root',
#              'carotid  artery',
#              'submandibular gland',
#              'mandibular  nerve',
#              'digastric muscles',
#              'lingual nerve',
#              'hypoglossal nerve',
#              'jugular vein',
#              'omohyoid muscle',
#              'scalene muscles',
#              'carotid artery',
#              'face nerve'],
#  'ANATOMY_MODIFIER': ['right',
#                       'natural',
#                       'superior',
#                       'inferior',
#                       'anterior',
#                       'medial',
#                       'anteriorly',
#                       'superiorly',
#                       'inferiorly',
#                       'level  III',
#                       'marginal',
#                       'left',
#                       'posteriorly',
#                       'deep'],
#  'OBSERVATION': ['Dissection', 'crease', 'preserved', 'lymph nodes', 'wound'],
#  'OBSERVATION_MODIFIER': ['elevated', 'preserved', 'all', 'branches'],
#  'ORDINAL': ['first'],
#  'PROBLEM': ['complication',
#              'Dissection',
#              'dissection',
#              'ptotic',
#              'fat, fascia,  and lymph nodes superiorly',
#              'the lymph nodes',
#              'Further dissection anteriorly',
#              'lymphoma',
#              'Small bleeding points'],
#  'QUANTITY': ['6 mL'],
#  'SENTIMENT': 0.24557,
#  'TEST': ['pressure points', 'the specimen', 'the  specimen', 'examination'],
#  'TREATMENT': ['General  anesthesia',
#                'right  selective neck dissection',
#                'A hockey-stick incision',
#                '2% lidocaine',
#                '1:100,000 epinephrine',
#                'Subplatysmal flaps',
#                'the skin incision',
#                'Bovie  electrocautery',
#                'Dissection',
#                'The dissection',
#                'the planned excision',
#                'Dissection over the omohyoid muscle',
#                'sterile salines',
#                'bipolar electrocautery',
#                'A #15 drain',
#                'stab incision',
#                'bulb suction',
#                'The platysmal layer',
#                '4-0 Vicryl',
#                'a simple interrupted fashion',
#                'a single running Prolene',
#                'Steri-Strips',
#                'Tegaderm',
#                'Telfa',
#                'extubated'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c76')}
# {'ANATOMY': ['shoulder',
#              'upper extremity',
#              'neck',
#              'subcutaneous tissue',
#              'deltopectoral',
#              'cephalic vein',
#              'deltoid',
#              'pectoralis',
#              'joint',
#              'biceps tendon',
#              'musculature',
#              'subscapularis',
#              'head',
#              'humeral',
#              'glenoid',
#              'humerus',
#              'acromion',
#              'synovium',
#              'skin',
#              'right upper  extremity'],
#  'ANATOMY_MODIFIER': ['right',
#                       'base',
#                       'anterior',
#                       'surrounding',
#                       'proximal',
#                       'posteriorly',
#                       'posterior',
#                       'rest'],
#  'CARDINAL': ['44', '17', '2', '4'],
#  'OBSERVATION': ['deep exposure',
#                  'incised',
#                  'rotator cuff',
#                  'split',
#                  'cuff',
#                  'central wear',
#                  'reamed',
#                  'cemented',
#                  'resected',
#                  'closed',
#                  'stable'],
#  'OBSERVATION_MODIFIER': ['tissue',
#                           'quality',
#                           '1 cm',
#                           'medial',
#                           'edge',
#                           'sized',
#                           'good',
#                           'contour',
#                           'proximally',
#                           'position',
#                           'reduced'],
#  'ORG': ['Mason-Allen', 'Pathology'],
#  'PERCENT': ['50-50%', '30%'],
#  'PROBLEM': ['large gelatinous material',
#              'rheumatoid arthritis',
#              'friable',
#              'diseased',
#              'her rheumatoid  arthritis',
#              'pannus',
#              'significant degenerative changes',
#              'Significant erosive changes',
#              'articular surface',
#              'the deficient rotator cuff',
#              'formal glenoid component',
#              "the patient's soft bone",
#              'extended articular surface head',
#              'stress',
#              'The  wound',
#              'estimated blood loss'],
#  'PRODUCT': ['#2 FiberWire'],
#  'QUANTITY': ['20 degrees', '90 degrees', '180 degrees', '250 mL'],
#  'SENTIMENT': 0.03089,
#  'TEST': ['bony  palpation',
#           'further evaluation',
#           'a complete labrectomy',
#           'further  inspection',
#           'manual palpation',
#           'instrument counts'],
#  'TREATMENT': ['Right Shoulder Hemiarthroplasty',
#                'a scalene block',
#                'Preoperative antibiotics',
#                'Betadine',
#                'a longitudinal skin incision',
#                'electrocautery',
#                'Dissection',
#                'A deep retractor',
#                'The clavipectoral fascia',
#                'suction',
#                'repair',
#                'retroversion',
#                'formal glenoid plasty',
#                'an 8 mm stem',
#                'The cement plug',
#                'an 8 mm Mini  Biomet stem',
#                'bacitracin  solution',
#                'power irrigation',
#                'Metzenbaum',
#                'Mayo scissors',
#                '#2  FiberWire',
#                'the subscapularis repair',
#                'bacitracin solution',
#                'The deltopectoral interval',
#                '0 Vicryl',
#                'Vicryl',
#                'a simple interrupted fashion',
#                'Monocryl',
#                'a running subcuticular pull',
#                'stitch',
#                'All sponge',
#                'Steri-Stripped',
#                'A  Polar Care ice machine',
#                'a shoulder immobilizer'],
#  'UNCERTAINTY': ['characteristic of', 'no evidence of'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c77')}
# {'ANATOMY': ['shoulder',
#              'left upper extremity',
#              'neck',
#              'portal',
#              'labrum',
#              'biceps',
#              'glenoid',
#              'glenohumeral ligament',
#              'axillary',
#              'articular',
#              'glenoid fossa',
#              'humeral head',
#              'supraspinatus',
#              'cuff',
#              'intra-articular subscapularis',
#              'left upper  extremity'],
#  'ANATOMY_MODIFIER': ['left',
#                       'base',
#                       'posterior',
#                       'anterior',
#                       'superior',
#                       "9 o'clock",
#                       'rim',
#                       'anchor',
#                       'middle',
#                       'inferior',
#                       'rest',
#                       'surface',
#                       'band'],
#  'CARDINAL': ['half'],
#  'DATE': ['one-year'],
#  'OBSERVATION': ['within normal limits',
#                  'negative drive',
#                  'pouch',
#                  'debrided',
#                  'good buttress',
#                  'stable'],
#  'OBSERVATION_MODIFIER': ["11 o'clock",
#                           'position',
#                           'acute',
#                           'rim',
#                           "10 o'clock"],
#  'PROBLEM': ['tears',
#              'a tear of the anterior-superior labrum',
#              'significant fraying',
#              'the tear',
#              'a complete  tear',
#              'Irregularities of the glenoid rim',
#              'loose bodies',
#              'defects',
#              'instability',
#              'fraying',
#              'neovascularization',
#              'bleeding bone',
#              'estimated blood loss',
#              'The wounds'],
#  'QUANTITY': ['4-0 nylon', 'less than 5  mL'],
#  'SENTIMENT': 0.11208,
#  'TEST': ['bony  palpation',
#           'a complete inventory of  the left shoulder',
#           'direct visualization',
#           'The  rotator interval',
#           'instrument counts'],
#  'TREATMENT': ['Shoulder Arthroscopic Labral Repair',
#                'scalene block',
#                'Preoperative antibiotics',
#                'Betadine',
#                'a 15 scalpel blade',
#                'the arthroscope',
#                'The arthroscope',
#                'instrumentation  and outflow',
#                'the radiofrequency device',
#                'surgery',
#                'instrumentation',
#                'a 4.5 full  radius shaver',
#                'further reparative  process',
#                'A 3.0 Bio-FASTak suture anchor',
#                'arthroscopic knot-tying techniques',
#                'a suture shuttle',
#                'a labral repair',
#                '#2 FiberWire',
#                'the buttress',
#                'good labral fixation',
#                'good fixation',
#                'an adequate arthroscopic labral repair',
#                'The instruments',
#                'All sponge',
#                'A Polar  Care ice machine',
#                'a shoulder immobilizer'],
#  'UNCERTAINTY': ['no  evidence of', 'no evidence of', 'no'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c78')}
# {'ANATOMY': ['bladder',
#              'vagina',
#              'cervix',
#              'uterus',
#              'umbilicus',
#              'peritoneal',
#              'pelvic',
#              'intestines',
#              'pelvis',
#              'ovaries',
#              'quadrant',
#              'blood vessels',
#              'round ligament',
#              'utero-ovarian vessels',
#              'broad ligament',
#              'fundus',
#              'ligament',
#              'ovarian vessels',
#              'uterine',
#              'uterine vessels',
#              'tissue',
#              'jaws',
#              'pedicles',
#              'abdomen',
#              'morcellator',
#              'cervical stump'],
#  'ANATOMY_MODIFIER': ['dorsal',
#                       'cavity',
#                       'right',
#                       'lower',
#                       'left',
#                       'fundus',
#                       'anterior',
#                       'leaf',
#                       'segment',
#                       'remainder',
#                       'shaft'],
#  'CARDINAL': ['8'],
#  'GPE': ['Trendelenburg'],
#  'OBSERVATION': ['lithotomy',
#                  'normal',
#                  'advanced',
#                  'excised',
#                  'irrigated',
#                  'removed',
#                  'high',
#                  'rotating blade',
#                  'myometrial tissue',
#                  'closed',
#                  'clean'],
#  'OBSERVATION_MODIFIER': ['laterally',
#                           'incised',
#                           'somewhat',
#                           'pressure',
#                           'cores',
#                           'position'],
#  'PROBLEM': ['Pneumoperitoneum',
#              'The incision',
#              'Some back-bleeding',
#              'the bleeding vessels on the uterus',
#              'some back-bleeding on the uterus',
#              'any residual bits of myometrial tissue',
#              'The left lower quadrant incision',
#              'The pneumoperitoneum',
#              'The incisions',
#              'difficulty'],
#  'QUANTITY': ['6 mmHg'],
#  'SENTIMENT': 0.06949,
#  'TEST': ['examination under anesthesia',
#           'the hanging drop method',
#           'an opening pressure',
#           'transillumination'],
#  'TREATMENT': ['Laparoscopic Supracervical Hysterectomy',
#                'General anesthesia',
#                'laparoscopic surgery',
#                'A Foley catheter',
#                'A weighted speculum',
#                'a Sims retractor',
#                'a Hulka clamp',
#                'The Hulka clamp',
#                'a sterile drape',
#                'Clean operating gloves',
#                'a stab incision',
#                'The Veress needle',
#                '3 liters of CO2',
#                'placement',
#                'the 5 mm laparoscopic sleeve',
#                'trocar',
#                'The trocar',
#                'the laparoscope',
#                'Additional trocars',
#                'the hysterectomy',
#                'a 10 mm incision',
#                'A 10 mm sleeve',
#                'transilluminating',
#                'another incision',
#                'a 12 mm sleeve',
#                'A suprapubic incision',
#                'a 5 mm sleeve',
#                'A suction-irrigation apparatus',
#                'the suprapubic port',
#                'A tenaculum',
#                'the right lower quadrant port',
#                'The harmonic ACE scalpel',
#                'the left lower quadrant port',
#                'The tenaculum',
#                'The harmonic ACE',
#                'the harmonic ACE',
#                'the LigaSure device',
#                'The instruments',
#                'the tenaculum',
#                'the harmonic ACE through the right lower quadrant port',
#                'traction',
#                'the ACE',
#                'the fallopian tube',
#                'prior cesarean section',
#                'this procedure',
#                'Kitner devices',
#                'this dissection',
#                'The Foley bulb',
#                'a drill technique',
#                'the active blade',
#                'the clamp',
#                'hemostasis',
#                'the suction irrigator',
#                'the sleeve in the left lower quadrant',
#                'The morcellator',
#                'the morcellator',
#                'A sheet of Interceed gauze',
#                'saline',
#                'a fascia closure device',
#                'a 0-Vicryl suture through the fascia',
#                'The right lower quadrant port',
#                'the fascia closure device',
#                'The remaining sleeves',
#                'the skin incisions',
#                'interrupted subcuticular 4-0 Vicryl sutures',
#                'Dry sterile dressings',
#                'anesthesia',
#                'the procedure'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c79')}
# {'ANATOMY': ['skin',
#              'fascia',
#              'midline',
#              'epigastric vessels',
#              'rectus abdominis muscle',
#              'rectus muscles',
#              'peritoneum',
#              'uterus',
#              'abdomen',
#              'liver',
#              'kidneys',
#              'bowel',
#              'ligament',
#              'utero-ovarian ligament',
#              'ureter',
#              'bladder',
#              'uterine',
#              'tissues',
#              'uterine arteries',
#              'cardinal ligaments',
#              'cul',
#              'colon',
#              'cervix',
#              'lower uterine',
#              'ureters',
#              'internal iliacs',
#              'adnexa',
#              'de-sac'],
#  'ANATOMY_MODIFIER': ['layer',
#                       'inferior',
#                       'lateral',
#                       'edges',
#                       'bilaterally',
#                       'midline',
#                       'upper',
#                       'right',
#                       'left',
#                       'lower',
#                       'segment',
#                       'overlying',
#                       'de-sac',
#                       'posterior',
#                       'cul-',
#                       'edge',
#                       'bilateral',
#                       'bifurcation'],
#  'CARDINAL': ['1'],
#  'DATE': ['21-week'],
#  'OBSERVATION': ['nicked',
#                  'clamped',
#                  'palpated',
#                  'normal',
#                  'pushed',
#                  'removed',
#                  'fibroid',
#                  'hemostasis',
#                  'irrigated',
#                  'closed',
#                  'incision'],
#  'OBSERVATION_MODIFIER': ['size', 'round', 'clamped', 'skeletonized'],
#  'ORDINAL': ['first'],
#  'PROBLEM': ['This incision',
#              'large fundal fibroid',
#              'large fibroid in the right lower uterine segment',
#              'The large fibroid',
#              'some endometriosis',
#              'small oozing coagulated'],
#  'SENTIMENT': 0.1016,
#  'TEST': ['Cystoscopy',
#           'Pelvic washings',
#           'pathology',
#           'Sponge, lap, needle, instrument counts'],
#  'TREATMENT': ['Subtotal Abdominal Hysterectomy',
#                'Cystoscopy',
#                'Bilateral Ureteral Stent Placement',
#                'general anesthesia',
#                'the dorsal lithotomy position',
#                'bilateral ureteral stents',
#                'A transverse incision',
#                'a scalpel',
#                'a Bovie',
#                'The Bovie',
#                'this incision',
#                'the Bovie',
#                'suture ligated',
#                '3-0 Vicryl free ties',
#                'pickups',
#                'Metzenbaum scissors',
#                "An O'Connor-O'Sullivan self-retaining retractor",
#                'moist laparotomy sponges',
#                'Mayo clamps',
#                'stent',
#                'The bladder flap',
#                'identical procedure on the left side',
#                'stent on the left',
#                'the vesicouterine peritoneal flap',
#                'a sponge stick',
#                'a Lahey clamp',
#                'a subtotal hysterectomy',
#                'figure-of-eight stitches of 0-Vicryl',
#                'Bovie',
#                'CoSeal',
#                'the cervical closure',
#                'laparotomy sponges',
#                'self-retaining retractors',
#                '3-0 Vicryl',
#                'the fascia',
#                'The subcutaneous layer',
#                'Monocryl',
#                'a subcuticular stitch',
#                'Benzoin',
#                'Steri-Strips',
#                'The bilateral ureteral stents',
#                'the procedure'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c7a')}
# {'ANATOMY': ['corneal',
#              'cornea',
#              'punch endothelial',
#              'lens',
#              'sclera',
#              'donor stroma',
#              'eye',
#              'eyelid'],
#  'ANATOMY_MODIFIER': ['host',
#                       'donor',
#                       'anterior',
#                       'chamber',
#                       'trephine',
#                       'left',
#                       "2 o'clock",
#                       'entire',
#                       'epithelial'],
#  'CARDINAL': ['Twelve'],
#  'OBSERVATION': ['donor rim',
#                  'pupil',
#                  'remaining tissue',
#                  'corneal rim',
#                  'donor tissue',
#                  'viscoelastic',
#                  'loose',
#                  'host tissue',
#                  'keratoconus',
#                  'ring reflex',
#                  'closed',
#                  'negative',
#                  'absent'],
#  'OBSERVATION_MODIFIER': ['caliber',
#                           '12.3 mm',
#                           '11.8 mm',
#                           'marked',
#                           'tips',
#                           'alignment',
#                           'edge',
#                           'remaining',
#                           'recipient',
#                           'four',
#                           'tension',
#                           'tightened',
#                           'position',
#                           'tighter',
#                           "9 o'clock",
#                           'evenly',
#                           'distributed',
#                           'buried',
#                           "4 o'clock",
#                           'surface'],
#  'ORDINAL': ['first'],
#  'ORG': ['BSS'],
#  'PERCENT': ['approximately 50%', '90%', '0.5%'],
#  'PERSON': ['Seidel'],
#  'PROBLEM': ['significant corneal ectasia',
#              'central subepithelial and stromal scarring',
#              'partial thickness scleral bites',
#              'slightly nasal',
#              'a slightly beveled edge',
#              'extremely floppy',
#              'a very thick cornea',
#              'the donor tissue',
#              'astigmatism',
#              'The wound',
#              'a knot buried',
#              'leaks',
#              'a micro leak',
#              'the wound',
#              'edematous',
#              'the edema',
#              'complications'],
#  'QUANTITY': ['10 mg/mL'],
#  'SENTIMENT': 0.04751,
#  'TEST': ["The patient's corneal diameter",
#           'a donor corneal punch',
#           'culture',
#           'a culture plate',
#           'The endothelial cell count'],
#  'TREATMENT': ['Penetrating Keratoplasty',
#                'general anesthesia',
#                'intubated',
#                'surgery on the right eye',
#                'A Schott lid speculum',
#                'Healon',
#                'a corneal shield',
#                'A scleral fixation ring',
#                'eight interrupted 5-0 Dacron sutures',
#                'a sterile marking pen',
#                'a forceps',
#                'brief gentle pressure',
#                'an 8.0 mm trephine',
#                'The mark',
#                'A 12-prong radial marker',
#                'a sterile marker',
#                'donor-host suture symmetry',
#                'a marker in the punch holes',
#                'The donor button',
#                'OptiSeal',
#                'Miochol',
#                'an ionized and 0.12 forceps',
#                'corneal scissors',
#                'Vannas scissors',
#                'the fixation ring',
#                'a spatula',
#                '0 nylon cardinal sutures',
#                'radial interrupted 10-0 nylon sutures',
#                'sutures',
#                'The cardinal sutures',
#                'the remaining sutures',
#                'Several temporal sutures',
#                'this adjustment',
#                'an additional 10-0 interrupted suture',
#                'A plastic ring',
#                'Two inferonasal sutures',
#                'additional 10-0 nylon running suture',
#                '90% stromal depth radial bites',
#                'The running suture tension',
#                'tying forceps',
#                'The interrupted suture knots',
#                'a 30-gauge cannula',
#                'irrigating',
#                'the Healon',
#                'An intracameral injection of vancomycin',
#                'a Weck-Cel sponge',
#                'fluorescein strip',
#                'an additional 10-0 nylon interrupted suture',
#                'the procedure',
#                'The scleral ring',
#                'the lid speculum',
#                'The drapes',
#                'Multiple drops of topical anesthetic',
#                'A drop of Alphagan',
#                'a drop of Timoptic',
#                'Polysporin ophthalmic ointment',
#                'Wet and dry sponges',
#                'A piece of 1 inch Transpore tape',
#                'a light eye patch',
#                'a metal eye shield'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c7b')}
# {'ANATOMY': ['head',
#              'eye',
#              'conjunctivae',
#              'cornea',
#              'lens',
#              'nucleus',
#              'corneal endothelium',
#              'corneal',
#              'eyelid',
#              'skin'],
#  'ANATOMY_MODIFIER': ['left',
#                       'anterior',
#                       'capsule',
#                       'lip',
#                       'central',
#                       'groove',
#                       'nucleus',
#                       'cortex',
#                       'chamber',
#                       'periocular'],
#  'CARDINAL': ['half'],
#  'OBSERVATION': ['capsulorrhexis', 'flow', 'stroma', 'wounds', 'speculum'],
#  'OBSERVATION_MODIFIER': ['curvilinear',
#                           'tip',
#                           "10 o'clock",
#                           'position',
#                           'rotated',
#                           'central',
#                           'sealed'],
#  'PERSON': ['Seidel'],
#  'PROBLEM': ['zonular weakness in the highly myopic eye',
#              'any cortical material',
#              'the clear corneal wound',
#              'the wound',
#              'The wounds'],
#  'PRODUCT': ['Viscoat', 'Osher'],
#  'QUANTITY': ['3 mL', "5 o'clock", "1 o'clock"],
#  'SENTIMENT': 0.03339,
#  'TEST': ['a fluid wave'],
#  'TREATMENT': ['Phacoemulsification',
#                'Intraocular Lens Implantation',
#                'the procedure',
#                'A Lieberman lid speculum',
#                '0.12 forceps',
#                'blunt Westcott scissors',
#                'an incision',
#                "Tenon's capsule",
#                'the inferonasal fornix',
#                '2% lidocaine',
#                'A 1.0 mm side-port blade',
#                'a paracentesis wound',
#                'Viscoat',
#                'the paracentesis',
#                'a 30 gauge cannula',
#                'A three-plane clear corneal incision',
#                'a 2.75 mm keratome blade',
#                'A cystitome',
#                'Capsulorrhexis forceps',
#                'the anterior capsule remnant',
#                'Hydrodissection of the lens cortex',
#                'the capsular bag',
#                'balanced salt solution',
#                'a 26 gauge cannula',
#                'the cannula',
#                'The cannula',
#                'gentle posterior pressure on the lens',
#                'caution',
#                'Healon',
#                'the clear corneal incision',
#                'A phacoemulsification handpiece',
#                'An Osher instrument',
#                'the paracentesis wound',
#                'the phacoemulsification tip',
#                'phacoemulsification',
#                'Irrigation',
#                'aspiration',
#                'capsule polishing',
#                'push the posterior capsule',
#                'an Alcon AcrySof SA60AT +9.0 diopter intraocular lens into the '
#                'bag',
#                'A Lester manipulator',
#                '10-0 nylon suture',
#                'the bag',
#                'gentle pressure on the intraocular lens',
#                'Balanced salt solution',
#                'the three-plane corneal incision',
#                'a Weck-Cel sponge',
#                'a fluorescein strip',
#                'the preplaced 10-0 nylon suture',
#                'Betadine',
#                'a drop of Alphagan',
#                'Wet and dry sponges',
#                'A metal eye shield'],
#  '_id': ObjectId('6395ce5b4fe5e6d8f7437c7c')}
